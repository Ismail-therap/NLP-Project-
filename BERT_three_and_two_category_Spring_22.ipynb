# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismail-therap/NLP-Project-Predicting-review-in-1-to-5-star-/blob/main/BERT_three_and_two_category_Spring_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
from transformers import BertTokenizer, TFBertForSequenceClassification
from transformers import InputExample, InputFeatures
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.6/site-packages (from transformers) (2022.4.24)
# Collecting filelock
#   Downloading filelock-3.4.1-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: dataclasses in ./.local/lib/python3.6/site-packages (from transformers) (0.8)
# Requirement already satisfied: importlib-metadata in ./.local/lib/python3.6/site-packages (from transformers) (3.10.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.37.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 9.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.5)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 11.8 MB/s eta 0:00:01
# Collecting packaging>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 4.4 MB/s  eta 0:00:01
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.22.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (603 kB)
#      |████████████████████████████████| 603 kB 12.0 MB/s eta 0:00:01
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 2.9 MB/s  eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.local/lib/python3.6/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in ./.local/lib/python3.6/site-packages (from importlib-metadata->transformers) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers) (2018.1.18)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/lib/python3/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in ./.local/lib/python3.6/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from sacremoses->transformers) (6.7)
# Requirement already satisfied: six in ./.local/lib/python3.6/site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.14.0)
# Installing collected packages: pyyaml, packaging, filelock, tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed filelock-3.4.1 huggingface-hub-0.4.0 packaging-21.3 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.18.0
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
#######################################
### -------- Load libraries ------- #### Load Huggingface transformers

from transformers import TFBertModel,  BertConfig, BertTokenizerFast# Then what you need from tensorflow.keras
from tensorflow.keras.layers import Input, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.utils import to_categorical# And pandas for data import + sklearn because you allways need sklearn
import pandas as pd
from sklearn.model_selection import train_test_split

import numpy as np

# %%
import pandas as pd

url='https://drive.google.com/file/d/1-vBpWV0H0cxX5jSeHlQIKXIiosMKwq2t/view?usp=sharing'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id
uniformed_review = pd.read_csv(dwn_url)

uniformed_review.head()
# Out:
#               business_id                                 name  \
# 0  0tGuFBrhM03I6TCLxDQhyg             Dancing Goats Coffee Bar
# 1  498F3rnpng6qv53S9diTSw                        Boston Market
# 2  7qBi3FMT2Oz4Jj1hCWwawA                     Bea's Nail Salon
# 3  K4X4nJVp0BcSn9Cvoavk8A                 T'Kilas Tacos & More
# 4  D6U1_06gxciRs1NoYjwhKQ  ESPN Club - Temporarily Unavailable
#
#                      address     city state postal_code   latitude  longitude  \
# 0    419 W Ponce De Leon Ave  Decatur    GA       30030  33.775805 -84.303269
# 1    4607 Braker Ln, Ste 100   Austin    TX       78759  30.399832 -97.744997
# 2              75 Blossom Ct   Boston    MA       02114  42.364891 -71.066818
# 3          1248 Clairmont Rd  Decatur    GA       30030  33.789815 -84.307511
# 4  2101 N Epcot Resorts Blvd  Orlando    FL       32836  28.368008 -81.555289
#
#    stars  review_count  is_open  \
# 0    4.0           358        1
# 1    3.0           102        1
# 2    3.0            23        1
# 3    3.0           115        0
# 4    2.5           303        1
#
#                                           attributes  \
# 0  {'RestaurantsPriceRange2': '1', 'WiFi': "'free...
# 1  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 2  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3  {'GoodForKids': 'True', 'BikeParking': 'False'...
# 4  {'GoodForKids': 'True', 'Caters': 'False', 'Re...
#
#                                           categories  \
# 0     Food, Coffee & Tea, Restaurants, Donuts, Cafes
# 1  American (Traditional), Caterers, Chicken Shop...
# 2                         Nail Salons, Beauty & Spas
# 3                               Mexican, Restaurants
# 4  Hotels, American (New), Event Planning & Servi...
#
#                                                hours                 user_id  \
# 0  {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...  IqUD0yoRq66PqnbSvRb5JA
# 1  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...  n2eAlOnBo1St1p7MWqBFmg
# 2  {'Monday': '9:30-19:0', 'Tuesday': '9:30-19:0'...  pHTrbVN4lzTlzqqnWEJYGw
# 3  {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...  Jfc8qYR3uEHIpU0nKzpObg
# 4  {'Monday': '0:0-0:0', 'Tuesday': '12:0-23:0', ...  Dw_oka5MVWOsaJCncfIXZQ
#
#    review_stars                                               text  \
# 0             1  OMG!! Hate! This place. Rude to me. On so many...
# 1             1  Why bother being open on Thanksgiving if you c...
# 2             1  The fact that on a Saturday afternoon this "sa...
# 3             1  I came to Los Loros in search of the "strong, ...
# 4             1  My fries were stale and my cheesesteak was mos...
#
#                   date
# 0  2018-10-06 14:34:51
# 1  2019-11-28 20:02:11
# 2  2009-07-11 19:59:46
# 3  2008-09-08 21:34:50
# 4  2018-01-14 01:41:50

# %%
# create a list of our conditions
conditions = [
    (uniformed_review['review_stars'] <= 2),
    (uniformed_review['review_stars'] == 3),
    (uniformed_review['review_stars'] > 3)
    ]

# create a list of the values we want to assign for each condition
values = ['Negative', 'Neutral', 'Positive']

# create a new column and use np.select to assign values to it using our lists as arguments
uniformed_review['three_star'] = np.select(conditions, values)

# display updated DataFrame
uniformed_review.head()
# Out:
#               business_id                                 name  \
# 0  0tGuFBrhM03I6TCLxDQhyg             Dancing Goats Coffee Bar
# 1  498F3rnpng6qv53S9diTSw                        Boston Market
# 2  7qBi3FMT2Oz4Jj1hCWwawA                     Bea's Nail Salon
# 3  K4X4nJVp0BcSn9Cvoavk8A                 T'Kilas Tacos & More
# 4  D6U1_06gxciRs1NoYjwhKQ  ESPN Club - Temporarily Unavailable
#
#                      address     city state postal_code   latitude  longitude  \
# 0    419 W Ponce De Leon Ave  Decatur    GA       30030  33.775805 -84.303269
# 1    4607 Braker Ln, Ste 100   Austin    TX       78759  30.399832 -97.744997
# 2              75 Blossom Ct   Boston    MA       02114  42.364891 -71.066818
# 3          1248 Clairmont Rd  Decatur    GA       30030  33.789815 -84.307511
# 4  2101 N Epcot Resorts Blvd  Orlando    FL       32836  28.368008 -81.555289
#
#    stars  review_count  is_open  \
# 0    4.0           358        1
# 1    3.0           102        1
# 2    3.0            23        1
# 3    3.0           115        0
# 4    2.5           303        1
#
#                                           attributes  \
# 0  {'RestaurantsPriceRange2': '1', 'WiFi': "'free...
# 1  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 2  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3  {'GoodForKids': 'True', 'BikeParking': 'False'...
# 4  {'GoodForKids': 'True', 'Caters': 'False', 'Re...
#
#                                           categories  \
# 0     Food, Coffee & Tea, Restaurants, Donuts, Cafes
# 1  American (Traditional), Caterers, Chicken Shop...
# 2                         Nail Salons, Beauty & Spas
# 3                               Mexican, Restaurants
# 4  Hotels, American (New), Event Planning & Servi...
#
#                                                hours                 user_id  \
# 0  {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...  IqUD0yoRq66PqnbSvRb5JA
# 1  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...  n2eAlOnBo1St1p7MWqBFmg
# 2  {'Monday': '9:30-19:0', 'Tuesday': '9:30-19:0'...  pHTrbVN4lzTlzqqnWEJYGw
# 3  {'Monday': '11:0-22:30', 'Tuesday': '11:0-22:3...  Jfc8qYR3uEHIpU0nKzpObg
# 4  {'Monday': '0:0-0:0', 'Tuesday': '12:0-23:0', ...  Dw_oka5MVWOsaJCncfIXZQ
#
#    review_stars                                               text  \
# 0             1  OMG!! Hate! This place. Rude to me. On so many...
# 1             1  Why bother being open on Thanksgiving if you c...
# 2             1  The fact that on a Saturday afternoon this "sa...
# 3             1  I came to Los Loros in search of the "strong, ...
# 4             1  My fries were stale and my cheesesteak was mos...
#
#                   date three_star
# 0  2018-10-06 14:34:51   Negative
# 1  2019-11-28 20:02:11   Negative
# 2  2009-07-11 19:59:46   Negative
# 3  2008-09-08 21:34:50   Negative
# 4  2018-01-14 01:41:50   Negative

# %%
reviews_smallest = uniformed_review[uniformed_review["three_star"] == 'Neutral']

## sampling negative review:
reviews_neg = uniformed_review[uniformed_review["three_star"] == 'Negative']
reviews_neg = reviews_neg.sample(n=reviews_smallest.shape[0])


## sampling positive review:
reviews_pos = uniformed_review[uniformed_review["three_star"] == 'Positive']
reviews_pos = reviews_pos.sample(n=reviews_smallest.shape[0])

uniformed_review = reviews_smallest.append([reviews_neg, reviews_pos])
uniformed_review.shape
# Out:
# (30000, 19)

# %% [markdown]
# # 3 star prediction

# %%
df = [uniformed_review.text,uniformed_review.three_star]
headers = ["Text", "Rating"]
data = pd. concat(df, axis=1, keys=headers)
data.head()
# Out:
#                                                     Text   Rating
# 20000  Wait in line for an hour before you wait insid...  Neutral
# 20001  Bell in Hand's a fun bar for karaoke on Tuesda...  Neutral
# 20002  Easy process. Not much to it, there were some ...  Neutral
# 20003  Fast food style of pho. Not a typical mom and ...  Neutral
# 20004  This is your standard Chinese food buffet. Lik...  Neutral

# %%
#data, data_test = train_test_split(data, test_size = 0.2)
#data['Rating'] = data['Rating'].apply(np.int64)
data['Rating'] = pd.Categorical(data['Rating'])

# Transform your output to numeric
data['Rating'] = data['Rating'].cat.codes
data, data_test = train_test_split(data, test_size = 0.2)

# %%
#######################################
### --------- Setup BERT ---------- ###

# Name of the BERT model to use
model_name = 'bert-base-uncased'

# Max length of tokens
max_length = 50

# Load transformers config and set output_hidden_states to False
config = BertConfig.from_pretrained(model_name)
config.output_hidden_states = False

# Load BERT tokenizer
tokenizer = BertTokenizerFast.from_pretrained(pretrained_model_name_or_path = model_name, config = config)

# Load the Transformers BERT model
transformer_model = TFBertModel.from_pretrained(model_name, config = config)
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
#######################################
### ------- Build the model ------- ###

# TF Keras documentation: https://www.tensorflow.org/api_docs/python/tf/keras/Model

# Load the MainLayer
bert = transformer_model.layers[0]

# Build your model input
input_ids = Input(shape=(max_length,), name='input_ids', dtype='int32')
# attention_mask = Input(shape=(max_length,), name='attention_mask', dtype='int32') 
# inputs = {'input_ids': input_ids, 'attention_mask': attention_mask}
inputs = {'input_ids': input_ids}

# Load the Transformers BERT model as a layer in a Keras model
bert_model = bert(inputs)[1]
dropout = Dropout(config.hidden_dropout_prob, name='pooled_output')
pooled_output = dropout(bert_model, training=False)

# Then build your model output
Rating = Dense(units=len(data.Rating.value_counts()), kernel_initializer=TruncatedNormal(stddev=config.initializer_range), name='Rating')(pooled_output)
#product = Dense(units=len(data.Product_label.value_counts()), kernel_initializer=TruncatedNormal(stddev=config.initializer_range), name='product')(pooled_output)
outputs = {'Rating': Rating}

# And combine it all in a model object
model = Model(inputs=inputs, outputs=outputs, name='BERT_MultiLabel_MultiClass')

# Take a look at the model
model.summary()
# Out:
# Model: "BERT_MultiLabel_MultiClass"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 50)]              0
# _________________________________________________________________
# bert (TFBertMainLayer)       TFBaseModelOutputWithPool 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# Rating (Dense)               (None, 3)                 2307
# =================================================================
# Total params: 109,484,547
# Trainable params: 109,484,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
#######################################
### ------- Train the model ------- ###

# Set an optimizer
optimizer = Adam(
    learning_rate=5e-05,
    epsilon=1e-08,
    decay=0.01,
    clipnorm=1.0)

# Set loss and metrics
loss = {'Rating': CategoricalCrossentropy(from_logits = True)}
metric = {'Rating': CategoricalAccuracy('accuracy')}

# Compile the model
model.compile(
    optimizer = optimizer,
    loss = loss, 
    metrics = metric)

# %%
# Ready output data for the model
y_rating = to_categorical(data['Rating'])

# %%
# Tokenize the input (takes some time)
x = tokenizer(
    text=data['Text'].to_list(),
    add_special_tokens=True,
    max_length=max_length,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = True,
    verbose = True)

# %%
import time
start = time.time()

# Fit the model
history = model.fit(
    # x={'input_ids': x['input_ids'], 'attention_mask': x['attention_mask']},
    x={'input_ids': x['input_ids']},
    y={'Rating': y_rating},
    validation_split=0.2,
    batch_size=100,
    epochs=10)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)


print("Execution time: "+"{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# Epoch 1/10
# 192/192 [==============================] - 3631s 19s/step - loss: 0.7711 - accuracy: 0.6404 - val_loss: 0.7071 - val_accuracy: 0.6760
# Epoch 2/10
# 192/192 [==============================] - 2572s 13s/step - loss: 0.5893 - accuracy: 0.7433 - val_loss: 0.7034 - val_accuracy: 0.6867
# Epoch 3/10
# 192/192 [==============================] - 2450s 13s/step - loss: 0.4876 - accuracy: 0.7951 - val_loss: 0.7287 - val_accuracy: 0.6908
# Epoch 4/10
# 192/192 [==============================] - 2155s 11s/step - loss: 0.4092 - accuracy: 0.8366 - val_loss: 0.8142 - val_accuracy: 0.6852
# Epoch 5/10
# 192/192 [==============================] - 1968s 10s/step - loss: 0.3490 - accuracy: 0.8660 - val_loss: 0.8732 - val_accuracy: 0.6846
# Epoch 6/10
# 192/192 [==============================] - 1984s 10s/step - loss: 0.2985 - accuracy: 0.8883 - val_loss: 0.9327 - val_accuracy: 0.6775
# Epoch 7/10
# 192/192 [==============================] - 1985s 10s/step - loss: 0.2584 - accuracy: 0.9054 - val_loss: 1.0022 - val_accuracy: 0.6742
# Epoch 8/10
# 192/192 [==============================] - 1978s 10s/step - loss: 0.2299 - accuracy: 0.9183 - val_loss: 1.0530 - val_accuracy: 0.6737
# Epoch 9/10
# 192/192 [==============================] - 1974s 10s/step - loss: 0.2080 - accuracy: 0.9269 - val_loss: 1.0738 - val_accuracy: 0.6740
# Epoch 10/10
# 192/192 [==============================] - 1975s 10s/step - loss: 0.1864 - accuracy: 0.9370 - val_loss: 1.1193 - val_accuracy: 0.6773
# Execution time: 06:17:52.10

# %% [markdown]
# # 2 star prediction

# %%
# Drop a row by condition
uniformed_review = uniformed_review[uniformed_review.three_star != 'Neutral']

# %%
uniformed_review.shape
# Out:
# (20000, 19)

# %%
df = [uniformed_review.text,uniformed_review.three_star]
headers = ["Text", "Rating"]
data = pd. concat(df, axis=1, keys=headers)
data.head()
# Out:
#                                                     Text    Rating
# 14064  Value Village just isn't the same as it used t...  Negative
# 10657  The decor is straight out of the basement from...  Negative
# 12929  I've eaten here for dinner before and consider...  Negative
# 19438  Came here on a late Thursday night. They are s...  Negative
# 1816   I got the fried combo seafood platter. It was ...  Negative

# %%
data['Rating'] = pd.Categorical(data['Rating'])

# Transform your output to numeric
data['Rating'] = data['Rating'].cat.codes
data, data_test = train_test_split(data, test_size = 0.2)

# %%
#######################################
### --------- Setup BERT ---------- ###

# Name of the BERT model to use
model_name = 'bert-base-uncased'

# Max length of tokens
max_length = 50

# Load transformers config and set output_hidden_states to False
config = BertConfig.from_pretrained(model_name)
config.output_hidden_states = False

# Load BERT tokenizer
tokenizer = BertTokenizerFast.from_pretrained(pretrained_model_name_or_path = model_name, config = config)

# Load the Transformers BERT model
transformer_model = TFBertModel.from_pretrained(model_name, config = config)
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
#######################################
### ------- Build the model ------- ###

# TF Keras documentation: https://www.tensorflow.org/api_docs/python/tf/keras/Model

# Load the MainLayer
bert = transformer_model.layers[0]

# Build your model input
input_ids = Input(shape=(max_length,), name='input_ids', dtype='int32')
# attention_mask = Input(shape=(max_length,), name='attention_mask', dtype='int32') 
# inputs = {'input_ids': input_ids, 'attention_mask': attention_mask}
inputs = {'input_ids': input_ids}

# Load the Transformers BERT model as a layer in a Keras model
bert_model = bert(inputs)[1]
dropout = Dropout(config.hidden_dropout_prob, name='pooled_output')
pooled_output = dropout(bert_model, training=False)

# Then build your model output
Rating = Dense(units=len(data.Rating.value_counts()), kernel_initializer=TruncatedNormal(stddev=config.initializer_range), name='Rating')(pooled_output)
#product = Dense(units=len(data.Product_label.value_counts()), kernel_initializer=TruncatedNormal(stddev=config.initializer_range), name='product')(pooled_output)
outputs = {'Rating': Rating}

# And combine it all in a model object
model = Model(inputs=inputs, outputs=outputs, name='BERT_MultiLabel_MultiClass')

# Take a look at the model
model.summary()
# Out:
# Model: "BERT_MultiLabel_MultiClass"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 50)]              0
# _________________________________________________________________
# bert (TFBertMainLayer)       TFBaseModelOutputWithPool 109482240
# _________________________________________________________________
# pooled_output (Dropout)      (None, 768)               0
# _________________________________________________________________
# Rating (Dense)               (None, 2)                 1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
#######################################
### ------- Train the model ------- ###

# Set an optimizer
optimizer = Adam(
    learning_rate=5e-05,
    epsilon=1e-08,
    decay=0.01,
    clipnorm=1.0)

# Set loss and metrics
loss = {'Rating': BinaryCrossentropy(from_logits = True)}
metric = {'Rating': CategoricalAccuracy('accuracy')}

# Compile the model
model.compile(
    optimizer = optimizer,
    loss = loss, 
    metrics = metric)

# %%
# Ready output data for the model
y_rating = to_categorical(data['Rating'])

# %%
# Tokenize the input (takes some time)
x = tokenizer(
    text=data['Text'].to_list(),
    add_special_tokens=True,
    max_length=max_length,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = True,
    verbose = True)

# %%
import time
start = time.time()

# Fit the model
history = model.fit(
    # x={'input_ids': x['input_ids'], 'attention_mask': x['attention_mask']},
    x={'input_ids': x['input_ids']},
    y={'Rating': y_rating},
    validation_split=0.2,
    batch_size=100,
    epochs=10)


end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)


print("Execution time: "+"{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# Epoch 1/10
# 128/128 [==============================] - 1864s 15s/step - loss: 0.0705 - accuracy: 0.9773 - val_loss: 0.3380 - val_accuracy: 0.8944
# Epoch 2/10
# 128/128 [==============================] - 1971s 15s/step - loss: 0.0467 - accuracy: 0.9867 - val_loss: 0.3802 - val_accuracy: 0.8969
# Epoch 3/10
# 128/128 [==============================] - 1559s 12s/step - loss: 0.0340 - accuracy: 0.9909 - val_loss: 0.4082 - val_accuracy: 0.8969
# Epoch 4/10
# 128/128 [==============================] - 1558s 12s/step - loss: 0.0261 - accuracy: 0.9932 - val_loss: 0.4310 - val_accuracy: 0.8950
# Epoch 5/10
# 128/128 [==============================] - 1561s 12s/step - loss: 0.0209 - accuracy: 0.9955 - val_loss: 0.4613 - val_accuracy: 0.8975
# Epoch 6/10
# 128/128 [==============================] - 1560s 12s/step - loss: 0.0188 - accuracy: 0.9958 - val_loss: 0.4598 - val_accuracy: 0.8963
# Epoch 7/10
# 128/128 [==============================] - 1546s 12s/step - loss: 0.0165 - accuracy: 0.9967 - val_loss: 0.4763 - val_accuracy: 0.8981
# Epoch 8/10
# 128/128 [==============================] - 1560s 12s/step - loss: 0.0141 - accuracy: 0.9973 - val_loss: 0.4813 - val_accuracy: 0.8953
# Epoch 9/10
# 128/128 [==============================] - 1558s 12s/step - loss: 0.0131 - accuracy: 0.9974 - val_loss: 0.5006 - val_accuracy: 0.8938
# Epoch 10/10
# 128/128 [==============================] - 1549s 12s/step - loss: 0.0125 - accuracy: 0.9973 - val_loss: 0.5056 - val_accuracy: 0.8944
# Execution time: 04:31:24.90
